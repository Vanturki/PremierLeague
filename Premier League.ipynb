# %%
# %pip install pandas
import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# تحميل كل الملفات
matches = pd.read_csv(r'C:\Users\Turki\Downloads\archive (1)\pl_24-25_matches_clean.csv')
players = pd.read_csv(r'C:\Users\Turki\Downloads\archive (1)\Squad_PlayerStats__stats_standard.csv')
results = pd.read_csv(r'C:\Users\Turki\Downloads\archive (1)\overwiev__results2024-202591_overall.csv')
nations = pd.read_csv(r'C:\Users\Turki\Downloads\archive (1)\overwiev__nations.csv')

print("✅ المباريات:", matches.shape)
print("✅ اللاعبون:", players.shape)
print("✅ الترتيب:", results.shape)
print("✅ الجنسيات:", nations.shape)
# Out:
# ✅ المباريات: (380, 15)
# ✅ اللاعبون: (574, 25)
# ✅ الترتيب: (20, 19)
# ✅ الجنسيات: (5, 5)

# %%
# استكشاف ملف المباريات
print("=== المباريات ===")
print(matches.columns.tolist())
matches.head()
# Out:
# === المباريات ===
# ['id', 'gameweek', 'dayofweek', 'date', 'start_time', 'home_team', 'home_xg', 'score', 'away_xg', 'away_team', 'attendance', 'venue', 'referee', 'notes', 'last_updated']
#    id  gameweek dayofweek        date start_time        home_team  home_xg  \
# 0   1         1       Fri  2024-08-16      20:00   Manchester Utd      2.4
# 1   2         1       Sat  2024-08-17      12:30     Ipswich Town      0.5
# 2   3         1       Sat  2024-08-17      15:00    Newcastle Utd      0.3
# 3   4         1       Sat  2024-08-17      15:00          Everton      0.5
# 4   5         1       Sat  2024-08-17      15:00  Nott'ham Forest      1.3
#
#   score  away_xg    away_team  attendance                 venue  \
# 0   1–0      0.4       Fulham         NaN          Old Trafford
# 1   0–2      2.6    Liverpool         NaN  Portman Road Stadium
# 2   1–0      1.8  Southampton         NaN        St James' Park
# 3   0–3      1.4     Brighton         NaN         Goodison Park
# ...

# %%
# استكشاف ملف اللاعبين
print("=== اللاعبون ===")
print(players.columns.tolist())
players.head()
# Out:
# === اللاعبون ===
# ['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'Playing Time_MP', 'Playing Time_Starts', 'Playing Time_Min', 'Playing Time_90s', 'Performance_Gls', 'Performance_Ast', 'Performance_G+A', 'Performance_G-PK', 'Performance_PK', 'Performance_PKatt', 'Performance_CrdY', 'Performance_CrdR', 'Per 90 Minutes_Gls', 'Per 90 Minutes_Ast', 'Per 90 Minutes_G+A', 'Per 90 Minutes_G-PK', 'Per 90 Minutes_G+A-PK', 'Matches']
#    Rk             Player   Nation Pos        Squad   Age    Born  \
# 0   1         Max Aarons  eng ENG  DF  Bournemouth  24.0  2000.0
# 1   2  Joshua Acheampong  eng ENG  DF      Chelsea  18.0  2006.0
# 2   3        Tyler Adams   us USA  MF  Bournemouth  25.0  1999.0
# 3   4   Tosin Adarabioyo  eng ENG  DF      Chelsea  26.0  1997.0
# 4   5      Simon Adingra   ci CIV  MF     Brighton  22.0  2002.0
#
#    Playing Time_MP  Playing Time_Starts  Playing Time_Min  ...  \
# 0                3                    1                86  ...
# ...

# %%
# أول نشوف أسماء الأعمدة المتعلقة بالأهداف
print(players.columns.tolist())
for col in players.columns:
    print(col)
# Out:
# ['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'Playing Time_MP', 'Playing Time_Starts', 'Playing Time_Min', 'Playing Time_90s', 'Performance_Gls', 'Performance_Ast', 'Performance_G+A', 'Performance_G-PK', 'Performance_PK', 'Performance_PKatt', 'Performance_CrdY', 'Performance_CrdR', 'Per 90 Minutes_Gls', 'Per 90 Minutes_Ast', 'Per 90 Minutes_G+A', 'Per 90 Minutes_G-PK', 'Per 90 Minutes_G+A-PK', 'Matches']
# Rk
# Player
# Nation
# Pos
# Squad
# Age
# Born
# Playing Time_MP
# Playing Time_Starts
# Playing Time_Min
# Playing Time_90s
# Performance_Gls
# Performance_Ast
# Performance_G+A
# Performance_G-PK
# Performance_PK
# Performance_PKatt
# Performance_CrdY
# Performance_CrdR
# Per 90 Minutes_Gls
# Per 90 Minutes_Ast
# Per 90 Minutes_G+A
# Per 90 Minutes_G-PK
# Per 90 Minutes_G+A-PK
# Matches

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
top_scorers = players[['Player', 'Squad', 'Performance_Gls']].sort_values(
    'Performance_Gls', ascending=False).head(10)

print(top_scorers)
# Out:
#                    Player              Squad  Performance_Gls
# 448         Mohamed Salah          Liverpool               29
# 252        Alexander Isak   Newcastle United               23
# 224        Erling Haaland    Manchester City               22
# 340          Bryan Mbeumo          Brentford               20
# 563            Chris Wood  Nottingham Forest               20
# 562           Yoane Wissa          Brentford               19
# 547         Ollie Watkins        Aston Villa               16
# 115         Matheus Cunha             Wolves               15
# 407           Cole Palmer            Chelsea               15
# 493  Jørgen Strand Larsen             Wolves               14

# %%
plt.figure(figsize=(12, 6))
plt.barh(top_scorers['Player'], top_scorers['Performance_Gls'], color='steelblue')
plt.xlabel('HOW MANY GOALS')
plt.title('TOP SCORERS 2024-2025')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

top_scorers = players[['Player', 'Squad', 'Performance_Gls']].sort_values(
    'Performance_Gls', ascending=False).head(10)

fig, ax = plt.subplots(figsize=(12, 7))
bars = ax.barh(top_scorers['Player'], top_scorers['Performance_Gls'], 
               color='steelblue', edgecolor='white')

# إضافة الأرقام على كل بار
for bar, val in zip(bars, top_scorers['Performance_Gls']):
    ax.text(bar.get_width() + 0.2, bar.get_y() + bar.get_height()/2,
            f'{int(val)} goals', va='center', fontsize=11, color='black')

ax.set_xlabel('Number of Goals', fontsize=12)
ax.set_title('Top 10 Scorers - Premier League 2024/25 ⚽', fontsize=14, fontweight='bold')
ax.invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Turki\AppData\Local\Temp\ipykernel_25040\1541225840.py:18: UserWarning: Glyph 9917 (\N{SOCCER BALL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Turki\Documents\New Recording\data analyst bootcamp\python\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9917 (\N{SOCCER BALL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# تحليل الهجوم - الأهداف + التمريرات
attack = players[['Player', 'Squad', 'Performance_Gls', 
                   'Performance_Ast', 'Performance_G+A']].sort_values(
                   'Performance_G+A', ascending=False).head(10)

print(attack)
# Out:
#              Player              Squad  Performance_Gls  Performance_Ast  \
# 448   Mohamed Salah          Liverpool               29               18
# 252  Alexander Isak   Newcastle United               23                6
# 340    Bryan Mbeumo          Brentford               20                7
# 224  Erling Haaland    Manchester City               22                3
# 547   Ollie Watkins        Aston Villa               16                8
# 407     Cole Palmer            Chelsea               15                8
# 562     Yoane Wissa          Brentford               19                4
# 563      Chris Wood  Nottingham Forest               20                3
# 115   Matheus Cunha             Wolves               15                6
# 64     Jarrod Bowen    West Ham United               13                8
#
#      Performance_G+A
# 448               47
# 252               29
# 340               27
# 224               25
# 547               24
# 407               23
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# ensure necessary modules are available (useful if the kernel was restarted)
if 'pd' not in globals():
    import pandas as pd
if 'np' not in globals():
    import numpy as np
if 'plt' not in globals():
    import matplotlib.pyplot as plt

# ensure the dataframe is loaded (useful if the kernel was restarted)
if 'players' not in globals():
    players = pd.read_csv(r'C:\Users\Turki\Downloads\archive (1)\Squad_PlayerStats__stats_standard.csv')

top10 = players[['Player', 'Performance_Gls', 'Performance_Ast']].sort_values(
        'Performance_Gls', ascending=False).head(10)

x = np.arange(len(top10['Player']))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 7))

bars1 = ax.bar(x - width/2, top10['Performance_Gls'], width, 
               label='Goals ⚽', color='steelblue')
bars2 = ax.bar(x + width/2, top10['Performance_Ast'], width, 
               label='Assists 🎯', color='orange')

# إضافة الأرقام فوق كل عمود
for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.1,
            str(int(bar.get_height())), ha='center', fontsize=9)

for bar in bars2:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.1,
            str(int(bar.get_height())), ha='center', fontsize=9)

ax.set_xticks(x)
ax.set_xticklabels(top10['Player'], rotation=45, ha='right')
ax.set_title('Goals vs Assists - Top 10 Players ⚽🎯', fontsize=14, fontweight='bold')
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Turki\AppData\Local\Temp\ipykernel_25040\121727384.py:39: UserWarning: Glyph 9917 (\N{SOCCER BALL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Turki\AppData\Local\Temp\ipykernel_25040\121727384.py:39: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Turki\Documents\New Recording\data analyst bootcamp\python\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9917 (\N{SOCCER BALL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Turki\Documents\New Recording\data analyst bootcamp\python\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# أكثر الفرق في البطاقات
cards = players.groupby('Squad')[['Performance_CrdY', 'Performance_CrdR']].sum()
cards = cards.sort_values('Performance_CrdY', ascending=False)

cards.plot(kind='bar', figsize=(14, 6), color=['gold', 'red'])
plt.title('Yellow & Red Cards by Team', fontsize=14, fontweight='bold')
plt.xlabel('Team')
plt.ylabel('Number of Cards')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
